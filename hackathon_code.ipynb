# %% [markdown]
# <a href="https://colab.research.google.com/github/anu352006/Ananya/blob/main/hackathon_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def analyze_health(age,bp,sugar):
  """Analyzes blood pressure and sugar levels based on age and provides potential health implications

  Args:
    age: Age of the person.
    bp: Blood Pressure value (systolic).
    sugar: sugar level value.
  Returns:
    A string indicating the status of BP and sugar levels and potential health implications. """
  # Define age groups and their corresponding Bp and sugar ranges
  age_groups = {
      "young_adult": (18,39),
      "adult":(40,59),
      "Middle_aged": (60,74),
      "Senior": (75,120) #Adjust upper limit as needed
  }
  # Sample BP and sugar ranges for each group (replace with accurate data)
  bp_ranges= {
      "Young_adult": (90,120),
      "adult": (75,110),
      "Middle_aged": (80,120),
      "Senior": (85,130)
  }
  # Determine age group
  for group, age_range in age_groups.items():
    if age_range[0] <= age <= age_range[1]:
      age_group = group
      break
    else:
      age_group = "unknown"

    # Check BP and Sugar level against age group ranges
    bp_status = "normal"
    sugar_status = "normal"
    if bp < bp_ranges[age_group][0]:
      bp_status = "low"
    elif bp > bp_ranges[age_group][1]:
      bp_status = "high"

    if sugar < sugar_ranges[age_group][0]:
      sugar_status = "low"
    elif sugar > sugar_ranges[age_group][1]:
      sugar_status = "high"

    # Provide feedback based on age group and health metrics
    print(f"You are in the {age_group} age group.")
    print(f"Blood Pressure: {bp_status}")
    print(f"Sugar Level: {sugar_status}")

    # Add more specific health implications based on age group and health metrics.

  # Get user input
  age = int(input("Enter your age: "))
  bp = float(input("Enter blood pressure (systolic): "))
  sugar = float(input("Enter sugar level: "))

analyze_health(age, bp, sugar)
# Out:
# Enter your age: 50
# Enter blood pressure (systolic): 100
# Enter sugar level: 20

# %%
def analyze_health(bp, sugar):
  """Analyzes blood pressure and sugar levels and provides potential health implications.

  Args:
    bp: Blood pressure value (systolic).
    sugar: Sugar level value.

  Returns:
    A string indicating the status of BP and sugar levels and potential health implications.
  """

  # Simple thresholds for demonstration purposes
  bp_normal = 120
  bp_high = 140
  sugar_normal = 100
  sugar_high = 140

  bp_status = "normal"
  sugar_status = "normal"

  if bp >= bp_high:
    bp_status = "high"
  elif bp < bp_normal:
    bp_status = "low"

  if sugar >= sugar_high:
    sugar_status = "high"
  elif sugar < sugar_normal:
    sugar_status = "low"

  print(f"Blood pressure: {bp_status}")
  print(f"Sugar level: {sugar_status}")

  if bp_status == "high" and sugar_status == "high":
    print("Potential health implications: Hypertension, diabetes, heart disease")
  elif bp_status == "high":
    print("Potential health implications: Hypertension, heart disease, stroke")
  elif sugar_status == "high":
    print("Potential health implications: Diabetes, kidney disease, nerve damage")
  elif bp_status == "low" and sugar_status == "low":
    print("Consult a doctor for low BP and sugar levels")

# Get user input
bp = float(input("Enter blood pressure (systolic): "))
sugar = float(input("Enter sugar level: "))

analyze_health(bp, sugar)
# Out:
# Enter blood pressure (systolic): 100
# Enter sugar level: 200
# Blood pressure: low
# Sugar level: high
# Potential health implications: Diabetes, kidney disease, nerve damage

# %%
def analyze_health(age, bp, sugar):
  """Analyzes blood pressure and sugar levels based on age and provides potential health implications.

  Args:
    age: Age of the person.
    bp: Blood pressure value (systolic).
    sugar: Sugar level value.

  Returns:
    A string indicating the status of BP and sugar levels and potential health implications.
  """

  # Define age groups and their corresponding BP and sugar ranges
  age_groups = {
      "young_adult": (18, 39),
      "adult": (40, 59),
      "middle_aged": (60, 74),
      "senior": (75, 120)  # Adjust upper limit as needed
  }

  # Sample BP and sugar ranges for each age group (replace with accurate data)
  bp_ranges = {
      "young_adult": (90, 120),
      "adult": (100, 130),
      "middle_aged": (110, 140),
      "senior": (120, 150)
  }

  sugar_ranges = {
      "young_adult": (70, 100),
      "adult": (75, 110),
      "middle_aged": (80, 120),
      "senior": (85, 130)
  }

  # Determine age group
  for group, age_range in age_groups.items():
    if age_range[0] <= age <= age_range[1]:
      age_group = group
      break
  else:
    age_group = "unknown"

  # Check BP and sugar levels against age group ranges
  bp_status = "normal"
  sugar_status = "normal"
  if bp < bp_ranges[age_group][0]:
    bp_status = "low"
  elif bp > bp_ranges[age_group][1]:
    bp_status = "high"

  if sugar < sugar_ranges[age_group][0]:
    sugar_status = "low"
  elif sugar > sugar_ranges[age_group][1]:
    sugar_status = "high"

  # Provide feedback based on age group and health metrics
  print(f"You are in the {age_group} age group.")
  print(f"Blood pressure: {bp_status}")
  print(f"Sugar level: {sugar_status}")

  # Add more specific health implications based on age group and health metrics
  # Example:
  if bp_status == "high" and sugar_status == "high":
    print("Potential complications: Heart disease, stroke, kidney disease")
  elif bp_status == "high":
    print("Potential complications: Heart disease, stroke")
  elif sugar_status == "high":
    print("Potential complications: Diabetes, kidney disease, nerve damage")

# Get user input
age = int(input("Enter your age: "))
bp = float(input("Enter blood pressure (systolic): "))
sugar = float(input("Enter sugar level: "))

analyze_health(age, bp, sugar)
# Out:
# Enter your age: 45
# Enter blood pressure (systolic): 49
# Enter sugar level: 300
# You are in the adult age group.
# Blood pressure: low
# Sugar level: high
# Potential complications: Diabetes, kidney disease, nerve damage
